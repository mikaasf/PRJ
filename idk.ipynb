# %%
import matplotlib.pyplot as plt
from deepface import DeepFace
import cv2
import matplotlib.pyplot

# %%
img_path = "pics/IMG_20201021_123059_442.jpg"

img = cv2.imread(img_path)

plt.imshow(img[:,:,::-1])

demography = DeepFace.analyze(img_path)
# Out:
# Action: race: 100%|██████████| 4/4 [00:04<00:00,  1.13s/it]

# %%
demography
# Out:
# {'emotion': {'angry': 1.8795631447955197,
#   'disgust': 0.044387946201807714,
#   'fear': 0.5801264436392255,
#   'happy': 90.84372629598066,
#   'sad': 0.546182114713536,
#   'surprise': 0.5583482128860696,
#   'neutral': 5.547665888349308},
#  'dominant_emotion': 'happy',
#  'age': 31,
#  'gender': 'Woman',
#  'race': {'asian': 0.4385140724480152,
#   'indian': 0.6413897033780813,
#   'black': 0.036587895010598004,
#   'white': 65.50774574279785,
#   'middle eastern': 21.002264320850372,
#   'latino hispanic': 12.37349808216095},
#  'dominant_race': 'white'}

# %%
img_path = "pics/DTp5p3Sg_400x400.jpg"

img = cv2.imread(img_path)

plt.imshow(img[:,:,::-1])

demography = DeepFace.analyze(img_path)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING:tensorflow:5 out of the last 35 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd8dc38c560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.95it/s]

# %%
demography
# Out:
# {'emotion': {'angry': 0.0930945563595742,
#   'disgust': 0.00017659074273979058,
#   'fear': 0.27668499387800694,
#   'happy': 90.55331349372864,
#   'sad': 0.8245176635682583,
#   'surprise': 0.0755340966861695,
#   'neutral': 8.176681399345398},
#  'dominant_emotion': 'happy',
#  'age': 31,
#  'gender': 'Man',
#  'race': {'asian': 9.59259569644928,
#   'indian': 5.4164838045835495,
#   'black': 2.1187156438827515,
#   'white': 32.75221884250641,
#   'middle eastern': 21.672457456588745,
#   'latino hispanic': 28.447532653808594},
#  'dominant_race': 'white'}

# %%
img_path = "pics/0B270372-44B4-45CD-A343-CED00452CD3D_4_5005_c.jpeg"

img = cv2.imread(img_path)

plt.imshow(img[:,:,::-1])

demography = DeepFace.analyze(img_path)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING:tensorflow:5 out of the last 42 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd845194200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
demography
# Out:
# {'emotion': {'angry': 0.05451152168910464,
#   'disgust': 3.9348839991958955e-07,
#   'fear': 0.023680564394325244,
#   'happy': 16.6079183349512,
#   'sad': 30.884516940655345,
#   'surprise': 8.091024424635865e-05,
#   'neutral': 52.42929487577616},
#  'dominant_emotion': 'neutral',
#  'age': 32,
#  'gender': 'Man',
#  'race': {'asian': 10.254676162639122,
#   'indian': 0.9431680471398775,
#   'black': 0.29869208742623476,
#   'white': 54.2075032940503,
#   'middle eastern': 9.79729848536271,
#   'latino hispanic': 24.498657941978223},
#  'dominant_race': 'white'}
